# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\nazmu\onedrive\desktop\ana\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\nazmu\onedrive\desktop\ana\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url +'&q=' + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | klyuchi
# Processing Record 7 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 8 of Set 1 | queenstown
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | mejit
# Processing Record 11 of Set 1 | kudahuvadhoo
# Processing Record 12 of Set 1 | remire-montjoly
# Processing Record 13 of Set 1 | wailua homesteads
# Processing Record 14 of Set 1 | bonthe
# Processing Record 15 of Set 1 | necochea
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | qamdo
# Processing Record 20 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | invercargill
# Processing Record 26 of Set 1 | west island
# Processing Record 27 of Set 1 | margaret river
# Processing Record 28 of Set 1 | sisimiut
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | tommot
# Processing Record 31 of Set 1 | blackmans bay
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | udachny
# Processing Record 34 of Set 1 | broken hill
# Processing Record 35 of Set 1 | krasnogvardeyskoye
# Processing Record 36 of Set 1 | nar'yan-mar
# Processing Record 37 of Set 1 | olonkinbyen
# Processing Record 38 of Set 1 | papatowai
# Processing Record 39 of Set 1 | berezovyy
# Processing Record 40 of Set 1 | whitehorse
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | qaqortoq
# Processing Record 43 of Set 1 | nehe
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | stanley
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | edinburgh of the seven seas
# Processing Record 49 of Set 1 | afaahiti
# Processing Record 50 of Set 1 | iskateley
# Processing Record 0 of Set 2 | hamilton
# Processing Record 1 of Set 2 | portland
# Processing Record 2 of Set 2 | college
# Processing Record 3 of Set 2 | badger
# Processing Record 4 of Set 2 | utrik
# Processing Record 5 of Set 2 | acarau
# Processing Record 6 of Set 2 | lautoka
# Processing Record 7 of Set 2 | dudinka
# Processing Record 8 of Set 2 | coruripe
# Processing Record 9 of Set 2 | dobrush
# Processing Record 10 of Set 2 | keflavik
# Processing Record 11 of Set 2 | greenville
# Processing Record 12 of Set 2 | juan griego
# Processing Record 13 of Set 2 | holualoa
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | biltine
# Processing Record 16 of Set 2 | mohpa
# Processing Record 17 of Set 2 | yangor
# City not found. Skipping...
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | basco
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | muisne
# Processing Record 22 of Set 2 | enewetak
# Processing Record 23 of Set 2 | cannonvale
# Processing Record 24 of Set 2 | winejok
# City not found. Skipping...
# Processing Record 25 of Set 2 | port mathurin
# Processing Record 26 of Set 2 | aykhal
# Processing Record 27 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 28 of Set 2 | ribadeo
# Processing Record 29 of Set 2 | taro
# Processing Record 30 of Set 2 | aleg
# Processing Record 31 of Set 2 | crane
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | colonia
# Processing Record 34 of Set 2 | puerto natales
# Processing Record 35 of Set 2 | beau vallon
# Processing Record 36 of Set 2 | egilsstadir
# Processing Record 37 of Set 2 | rawai
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | haiku-pauwela
# Processing Record 41 of Set 2 | nova xavantina
# Processing Record 42 of Set 2 | ust'-barguzin
# Processing Record 43 of Set 2 | kailua-kona
# Processing Record 44 of Set 2 | dax
# Processing Record 45 of Set 2 | bhinga
# Processing Record 46 of Set 2 | ixtapa
# Processing Record 47 of Set 2 | sarupathar
# Processing Record 48 of Set 2 | taber
# Processing Record 49 of Set 2 | sarmasu
# Processing Record 0 of Set 3 | grand gaube
# Processing Record 1 of Set 3 | gornopravdinsk
# Processing Record 2 of Set 3 | san salvador
# Processing Record 3 of Set 3 | den burg
# Processing Record 4 of Set 3 | ust'-uda
# Processing Record 5 of Set 3 | weno
# Processing Record 6 of Set 3 | uturoa
# Processing Record 7 of Set 3 | cide
# Processing Record 8 of Set 3 | greymouth
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | gueltat zemmour
# City not found. Skipping...
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | lensk
# Processing Record 13 of Set 3 | puerto aysen
# Processing Record 14 of Set 3 | san pedro pochutla
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | barra de santo antonio
# Processing Record 17 of Set 3 | rupea
# Processing Record 18 of Set 3 | amungan
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | jacmel
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | arraias
# Processing Record 23 of Set 3 | la passe
# Processing Record 24 of Set 3 | hirara
# Processing Record 25 of Set 3 | tucupita
# Processing Record 26 of Set 3 | ponta delgada
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | sechura
# Processing Record 29 of Set 3 | calabozo
# Processing Record 30 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 31 of Set 3 | nadym
# Processing Record 32 of Set 3 | napili-honokowai
# Processing Record 33 of Set 3 | kyabe
# Processing Record 34 of Set 3 | khandud
# Processing Record 35 of Set 3 | gadzhiyevo
# Processing Record 36 of Set 3 | arkhangel'sk
# Processing Record 37 of Set 3 | al-`ula
# City not found. Skipping...
# Processing Record 38 of Set 3 | kletnya
# Processing Record 39 of Set 3 | labuan
# Processing Record 40 of Set 3 | midvagur
# Processing Record 41 of Set 3 | meadow lakes
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | cozumel
# Processing Record 44 of Set 3 | aasiaat
# Processing Record 45 of Set 3 | skeldon
# Processing Record 46 of Set 3 | priargunsk
# Processing Record 47 of Set 3 | port pirie
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | namibe
# Processing Record 0 of Set 4 | mount gambier
# Processing Record 1 of Set 4 | el nido
# Processing Record 2 of Set 4 | derzhavinsk
# Processing Record 3 of Set 4 | kingston
# Processing Record 4 of Set 4 | sultanpur
# Processing Record 5 of Set 4 | dunedin
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | hawaiian paradise park
# Processing Record 8 of Set 4 | dzhalagash
# Processing Record 9 of Set 4 | ust'-ilimsk
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | vila franca do campo
# Processing Record 12 of Set 4 | anadyr
# Processing Record 13 of Set 4 | susuman
# Processing Record 14 of Set 4 | ola
# Processing Record 15 of Set 4 | krivosheino
# Processing Record 16 of Set 4 | badou
# Processing Record 17 of Set 4 | dalai
# Processing Record 18 of Set 4 | kolonia
# Processing Record 19 of Set 4 | pratt
# Processing Record 20 of Set 4 | kayes
# Processing Record 21 of Set 4 | tongouson
# Processing Record 22 of Set 4 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 23 of Set 4 | nakamura
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | vaijapur
# Processing Record 27 of Set 4 | mount pearl
# Processing Record 28 of Set 4 | saipan
# Processing Record 29 of Set 4 | chajari
# Processing Record 30 of Set 4 | kilindoni
# Processing Record 31 of Set 4 | tura
# Processing Record 32 of Set 4 | cabedelo
# Processing Record 33 of Set 4 | isafjordur
# Processing Record 34 of Set 4 | arue
# Processing Record 35 of Set 4 | katsuura
# Processing Record 36 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 4 | kone
# Processing Record 38 of Set 4 | altania
# Processing Record 39 of Set 4 | tofol
# Processing Record 40 of Set 4 | tulun
# Processing Record 41 of Set 4 | red hill
# Processing Record 42 of Set 4 | constantia
# Processing Record 43 of Set 4 | daru
# Processing Record 44 of Set 4 | puerto deseado
# Processing Record 45 of Set 4 | longyearbyen
# Processing Record 46 of Set 4 | ocean city
# Processing Record 47 of Set 4 | letlhakane
# Processing Record 48 of Set 4 | port elizabeth
# Processing Record 49 of Set 4 | lihue
# Processing Record 0 of Set 5 | sangkhla buri
# Processing Record 1 of Set 5 | port isabel
# Processing Record 2 of Set 5 | nemuro
# Processing Record 3 of Set 5 | sumenep
# Processing Record 4 of Set 5 | dedougou
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | las vegas
# Processing Record 7 of Set 5 | ust-nera
# Processing Record 8 of Set 5 | banda aceh
# Processing Record 9 of Set 5 | doka
# Processing Record 10 of Set 5 | smithers
# Processing Record 11 of Set 5 | colac
# Processing Record 12 of Set 5 | cooper's town
# Processing Record 13 of Set 5 | ar ruways
# Processing Record 14 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 15 of Set 5 | zhezqazghan
# Processing Record 16 of Set 5 | howrah
# Processing Record 17 of Set 5 | mil'kovo
# Processing Record 18 of Set 5 | general villegas
# Processing Record 19 of Set 5 | hampton bays
# Processing Record 20 of Set 5 | walvis bay
# Processing Record 21 of Set 5 | hadibu
# Processing Record 22 of Set 5 | nukunonu
# City not found. Skipping...
# Processing Record 23 of Set 5 | bikenibeu village
# Processing Record 24 of Set 5 | hermanus
# Processing Record 25 of Set 5 | djamaa
# Processing Record 26 of Set 5 | fonte boa
# Processing Record 27 of Set 5 | kupang
# Processing Record 28 of Set 5 | cefalu
# Processing Record 29 of Set 5 | tannum sands
# Processing Record 30 of Set 5 | asau
# Processing Record 31 of Set 5 | bodo
# Processing Record 32 of Set 5 | atafu village
# Processing Record 33 of Set 5 | la possession
# Processing Record 34 of Set 5 | orchard mesa
# Processing Record 35 of Set 5 | esquel
# Processing Record 36 of Set 5 | saint-pierre
# Processing Record 37 of Set 5 | chibougamau
# Processing Record 38 of Set 5 | lagoa formosa
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | nuku'alofa
# Processing Record 41 of Set 5 | flin flon
# Processing Record 42 of Set 5 | opuwo
# Processing Record 43 of Set 5 | kayyerkan
# Processing Record 44 of Set 5 | karratha
# Processing Record 45 of Set 5 | kamaishi
# Processing Record 46 of Set 5 | magdagachi
# Processing Record 47 of Set 5 | nanao
# Processing Record 48 of Set 5 | forest city
# Processing Record 49 of Set 5 | zhumysker
# Processing Record 0 of Set 6 | fada
# Processing Record 1 of Set 6 | hovd
# Processing Record 2 of Set 6 | puerto baquerizo moreno
# Processing Record 3 of Set 6 | merizo village
# Processing Record 4 of Set 6 | nuevo arraijan
# Processing Record 5 of Set 6 | el fasher
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | dombarovskiy
# Processing Record 8 of Set 6 | fairfax
# Processing Record 9 of Set 6 | mangrol
# Processing Record 10 of Set 6 | salekhard
# Processing Record 11 of Set 6 | bumba
# Processing Record 12 of Set 6 | bamyan
# Processing Record 13 of Set 6 | acapulco de juarez
# Processing Record 14 of Set 6 | stephenville
# Processing Record 15 of Set 6 | kendari
# Processing Record 16 of Set 6 | aripuana
# Processing Record 17 of Set 6 | ta`u
# Processing Record 18 of Set 6 | balykshi
# Processing Record 19 of Set 6 | chonchi
# Processing Record 20 of Set 6 | kirakira
# Processing Record 21 of Set 6 | ouesso
# Processing Record 22 of Set 6 | salida
# Processing Record 23 of Set 6 | villa gesell
# Processing Record 24 of Set 6 | yarmouth
# Processing Record 25 of Set 6 | selfoss
# Processing Record 26 of Set 6 | birao
# Processing Record 27 of Set 6 | xapuri
# Processing Record 28 of Set 6 | tazovsky
# Processing Record 29 of Set 6 | yuzhno-kurilsk
# Processing Record 30 of Set 6 | dayr al 'asafir
# City not found. Skipping...
# Processing Record 31 of Set 6 | pyhajarvi
# Processing Record 32 of Set 6 | porto novo
# Processing Record 33 of Set 6 | kristiansund
# Processing Record 34 of Set 6 | mantua
# Processing Record 35 of Set 6 | kununurra
# Processing Record 36 of Set 6 | katabu
# Processing Record 37 of Set 6 | kodiak
# Processing Record 38 of Set 6 | usogorsk
# Processing Record 39 of Set 6 | alofi
# Processing Record 40 of Set 6 | kerema
# Processing Record 41 of Set 6 | kapuskasing
# Processing Record 42 of Set 6 | mananara
# Processing Record 43 of Set 6 | shimoda
# Processing Record 44 of Set 6 | chabahar
# Processing Record 45 of Set 6 | tanout
# Processing Record 46 of Set 6 | st. john's
# Processing Record 47 of Set 6 | dompu
# Processing Record 48 of Set 6 | alice springs
# Processing Record 49 of Set 6 | quellon
# Processing Record 0 of Set 7 | timimoun
# Processing Record 1 of Set 7 | zhigalovo
# Processing Record 2 of Set 7 | puerto armuelles
# Processing Record 3 of Set 7 | binzhou
# Processing Record 4 of Set 7 | inhambane
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | itoman
# Processing Record 7 of Set 7 | el calafate
# Processing Record 8 of Set 7 | champerico
# Processing Record 9 of Set 7 | lermontov
# Processing Record 10 of Set 7 | midelt
# Processing Record 11 of Set 7 | dwarka
# Processing Record 12 of Set 7 | pimentel
# Processing Record 13 of Set 7 | kapa'a
# Processing Record 14 of Set 7 | ebon
# Processing Record 15 of Set 7 | lalsot
# Processing Record 16 of Set 7 | ouro preto do oeste
# Processing Record 17 of Set 7 | linden
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | puerto santa
# Processing Record 20 of Set 7 | machico
# Processing Record 21 of Set 7 | vikulovo
# Processing Record 22 of Set 7 | san antonio de pale
# Processing Record 23 of Set 7 | tarawa
# Processing Record 24 of Set 7 | sawakin
# Processing Record 25 of Set 7 | shahada
# Processing Record 26 of Set 7 | new norfolk
# Processing Record 27 of Set 7 | jeddah
# Processing Record 28 of Set 7 | esfarayen
# Processing Record 29 of Set 7 | plettenberg bay
# Processing Record 30 of Set 7 | juhaynah
# Processing Record 31 of Set 7 | tual
# Processing Record 32 of Set 7 | kurchum
# Processing Record 33 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 34 of Set 7 | mount isa
# Processing Record 35 of Set 7 | pangkalanbuun
# Processing Record 36 of Set 7 | el obeid
# Processing Record 37 of Set 7 | lazaro cardenas
# Processing Record 38 of Set 7 | obihiro
# Processing Record 39 of Set 7 | sabang
# Processing Record 40 of Set 7 | faya-largeau
# Processing Record 41 of Set 7 | umm kaddadah
# Processing Record 42 of Set 7 | devils lake
# Processing Record 43 of Set 7 | pontianak
# Processing Record 44 of Set 7 | nieves
# Processing Record 45 of Set 7 | newman
# Processing Record 46 of Set 7 | zaozersk
# Processing Record 47 of Set 7 | novoazovs'k
# Processing Record 48 of Set 7 | avarua
# Processing Record 49 of Set 7 | carnarvon
# Processing Record 0 of Set 8 | bairnsdale
# Processing Record 1 of Set 8 | camacupa
# Processing Record 2 of Set 8 | tsiombe
# Processing Record 3 of Set 8 | margate
# Processing Record 4 of Set 8 | minas de marcona
# Processing Record 5 of Set 8 | masterton
# Processing Record 6 of Set 8 | birjand
# Processing Record 7 of Set 8 | vorgashor
# Processing Record 8 of Set 8 | freetown
# Processing Record 9 of Set 8 | namdrik
# Processing Record 10 of Set 8 | luderitz
# Processing Record 11 of Set 8 | bu'aale
# Processing Record 12 of Set 8 | ilo
# Processing Record 13 of Set 8 | dalandzadgad
# Processing Record 14 of Set 8 | antofagasta
# Processing Record 15 of Set 8 | laiyang
# Processing Record 16 of Set 8 | horta
# Processing Record 17 of Set 8 | vadso
# Processing Record 18 of Set 8 | tromso
# Processing Record 19 of Set 8 | madimba
# Processing Record 20 of Set 8 | miri
# Processing Record 21 of Set 8 | zlatoust
# Processing Record 22 of Set 8 | bhamo
# Processing Record 23 of Set 8 | xichang
# Processing Record 24 of Set 8 | itamarandiba
# Processing Record 25 of Set 8 | bouar
# Processing Record 26 of Set 8 | suva
# Processing Record 27 of Set 8 | kenora
# Processing Record 28 of Set 8 | luwuk
# Processing Record 29 of Set 8 | mermoz boabab
# Processing Record 30 of Set 8 | hilo
# Processing Record 31 of Set 8 | mahalapye
# Processing Record 32 of Set 8 | nyala
# Processing Record 33 of Set 8 | flying fish cove
# Processing Record 34 of Set 8 | eyl
# Processing Record 35 of Set 8 | oban
# Processing Record 36 of Set 8 | 'ayy
# City not found. Skipping...
# Processing Record 37 of Set 8 | gualaceo
# Processing Record 38 of Set 8 | chodavaram
# Processing Record 39 of Set 8 | hotan
# Processing Record 40 of Set 8 | severo-yeniseyskiy
# Processing Record 41 of Set 8 | liman
# Processing Record 42 of Set 8 | huarmey
# Processing Record 43 of Set 8 | nampula
# Processing Record 44 of Set 8 | big bend
# Processing Record 45 of Set 8 | lalmonirhat
# Processing Record 46 of Set 8 | rumoi
# Processing Record 47 of Set 8 | gobabis
# Processing Record 48 of Set 8 | inongo
# Processing Record 49 of Set 8 | rio verde de mato grosso
# Processing Record 0 of Set 9 | santo antonio
# Processing Record 1 of Set 9 | tolanaro
# Processing Record 2 of Set 9 | i-n-salah
# Processing Record 3 of Set 9 | northam
# Processing Record 4 of Set 9 | talavera de la reina
# Processing Record 5 of Set 9 | rubtsovsk
# Processing Record 6 of Set 9 | thinadhoo
# Processing Record 7 of Set 9 | hukumati azrah
# Processing Record 8 of Set 9 | dryden
# Processing Record 9 of Set 9 | la cruz
# Processing Record 10 of Set 9 | san luis
# Processing Record 11 of Set 9 | garachico
# Processing Record 12 of Set 9 | tahe
# Processing Record 13 of Set 9 | praia da vitoria
# Processing Record 14 of Set 9 | arteche
# Processing Record 15 of Set 9 | amos
# Processing Record 16 of Set 9 | sinabang
# Processing Record 17 of Set 9 | vallegrande
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | mwene-ditu
# Processing Record 20 of Set 9 | al wajh
# Processing Record 21 of Set 9 | kawanoecho
# Processing Record 22 of Set 9 | miguel auza
# Processing Record 23 of Set 9 | manda
# Processing Record 24 of Set 9 | magadan
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | kittila
# Processing Record 27 of Set 9 | el bauga
# Processing Record 28 of Set 9 | serhiyivka
# Processing Record 29 of Set 9 | guarapari
# Processing Record 30 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 31 of Set 9 | pacasmayo
# Processing Record 32 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 33 of Set 9 | road town
# Processing Record 34 of Set 9 | miquelon
# Processing Record 35 of Set 9 | rio grande
# Processing Record 36 of Set 9 | pariyapuram
# Processing Record 37 of Set 9 | el daein
# City not found. Skipping...
# Processing Record 38 of Set 9 | nogliki
# Processing Record 39 of Set 9 | san patricio
# Processing Record 40 of Set 9 | al jawf
# Processing Record 41 of Set 9 | sandnessjoen
# Processing Record 42 of Set 9 | rio ceballos
# Processing Record 43 of Set 9 | kolonia town
# Processing Record 44 of Set 9 | natal
# Processing Record 45 of Set 9 | ulsteinvik
# Processing Record 46 of Set 9 | bandarbeyla
# Processing Record 47 of Set 9 | praya
# Processing Record 48 of Set 9 | fort bragg
# Processing Record 49 of Set 9 | gufeng
# Processing Record 0 of Set 10 | burabay
# Processing Record 1 of Set 10 | argo
# Processing Record 2 of Set 10 | bukoba
# Processing Record 3 of Set 10 | west richland
# Processing Record 4 of Set 10 | coahuayana de hidalgo
# Processing Record 5 of Set 10 | nova vicosa
# Processing Record 6 of Set 10 | sao gabriel da cachoeira
# Processing Record 7 of Set 10 | uthal
# Processing Record 8 of Set 10 | ishigaki
# Processing Record 9 of Set 10 | kavaratti
# Processing Record 10 of Set 10 | antsohihy
# Processing Record 11 of Set 10 | saudarkrokur
# Processing Record 12 of Set 10 | pandan
# Processing Record 13 of Set 10 | buka
# Processing Record 14 of Set 10 | kotel'nich
# Processing Record 15 of Set 10 | tinajo
# Processing Record 16 of Set 10 | kabalo
# Processing Record 17 of Set 10 | sandakan
# Processing Record 18 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 19 of Set 10 | dalnegorsk
# Processing Record 20 of Set 10 | rabaul
# Processing Record 21 of Set 10 | igarka
# Processing Record 22 of Set 10 | pacocha
# Processing Record 23 of Set 10 | mankivka
# Processing Record 24 of Set 10 | castillos
# Processing Record 25 of Set 10 | shanwei
# Processing Record 26 of Set 10 | japekrom
# City not found. Skipping...
# Processing Record 27 of Set 10 | bechar
# Processing Record 28 of Set 10 | chalus
# Processing Record 29 of Set 10 | fale old settlement
# Processing Record 30 of Set 10 | bardai
# Processing Record 31 of Set 10 | suez
# Processing Record 32 of Set 10 | cairns city
# City not found. Skipping...
# Processing Record 33 of Set 10 | brookings
# Processing Record 34 of Set 10 | hammerfest
# Processing Record 35 of Set 10 | amga
# Processing Record 36 of Set 10 | gizo
# Processing Record 37 of Set 10 | aitape
# Processing Record 38 of Set 10 | turpan
# Processing Record 39 of Set 10 | moab
# Processing Record 40 of Set 10 | chhagalnaiya
# Processing Record 41 of Set 10 | mbarara
# Processing Record 42 of Set 10 | mutare
# Processing Record 43 of Set 10 | demyansk
# Processing Record 44 of Set 10 | mitsamiouli
# Processing Record 45 of Set 10 | kemijarvi
# Processing Record 46 of Set 10 | baley
# Processing Record 47 of Set 10 | ibarreta
# Processing Record 48 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 49 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 0 of Set 11 | bride
# Processing Record 1 of Set 11 | whistler
# Processing Record 2 of Set 11 | port douglas
# Processing Record 3 of Set 11 | bandon
# Processing Record 4 of Set 11 | havre
# Processing Record 5 of Set 11 | cururupu
# Processing Record 6 of Set 11 | amaigbo
# Processing Record 7 of Set 11 | ghanzi
# Processing Record 8 of Set 11 | bahir dar
# Processing Record 9 of Set 11 | boguchany
# Processing Record 10 of Set 11 | kaa-khem
# Processing Record 11 of Set 11 | kapren
# Processing Record 12 of Set 11 | abashiri
# Processing Record 13 of Set 11 | porangatu
# Processing Record 14 of Set 11 | alliance
# Processing Record 15 of Set 11 | broadstairs
# Processing Record 16 of Set 11 | borzya
# Processing Record 17 of Set 11 | uliastay
# Processing Record 18 of Set 11 | arno
# Processing Record 19 of Set 11 | camabatela
# Processing Record 20 of Set 11 | orsk
# Processing Record 21 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 22 of Set 11 | malango
# Processing Record 23 of Set 11 | baissa
# Processing Record 24 of Set 11 | bereket
# Processing Record 25 of Set 11 | rongelap
# Processing Record 26 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 11 | leava
# Processing Record 28 of Set 11 | tidjikja
# Processing Record 29 of Set 11 | fang
# Processing Record 30 of Set 11 | torteval
# City not found. Skipping...
# Processing Record 31 of Set 11 | vanimo
# Processing Record 32 of Set 11 | vilyuchinsk
# Processing Record 33 of Set 11 | vrangel'
# Processing Record 34 of Set 11 | novaya igirma
# Processing Record 35 of Set 11 | mulayjah
# Processing Record 36 of Set 11 | ketchikan
# Processing Record 37 of Set 11 | panadura
# Processing Record 38 of Set 11 | tarifa
# Processing Record 39 of Set 11 | prince rupert
# Processing Record 40 of Set 11 | monrovia
# Processing Record 41 of Set 11 | wynyard
# Processing Record 42 of Set 11 | assab
# Processing Record 43 of Set 11 | petropavlivka
# Processing Record 44 of Set 11 | puerto real
# Processing Record 45 of Set 11 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 46 of Set 11 | isiro
# Processing Record 47 of Set 11 | bubaque
# Processing Record 48 of Set 11 | codrington
# Processing Record 49 of Set 11 | verkhnevilyuysk
# Processing Record 0 of Set 12 | yekaterinoslavka
# Processing Record 1 of Set 12 | regina
# Processing Record 2 of Set 12 | felipe carrillo puerto
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | adrar
# Processing Record 5 of Set 12 | nguigmi
# Processing Record 6 of Set 12 | puerto el triunfo
# Processing Record 7 of Set 12 | gadani
# Processing Record 8 of Set 12 | karlskoga
# Processing Record 9 of Set 12 | puerto colombia
# Processing Record 10 of Set 12 | palmer
# Processing Record 11 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 12 of Set 12 | gornozavodsk
# Processing Record 13 of Set 12 | mrakovo
# Processing Record 14 of Set 12 | yemva
# Processing Record 15 of Set 12 | corumba
# Processing Record 16 of Set 12 | port saint john's
# Processing Record 17 of Set 12 | gornyatskiy
# Processing Record 18 of Set 12 | mahdia
# Processing Record 19 of Set 12 | malpe
# Processing Record 20 of Set 12 | pangody
# Processing Record 21 of Set 12 | baruun-urt
# Processing Record 22 of Set 12 | alchevs'k
# Processing Record 23 of Set 12 | south grafton
# Processing Record 24 of Set 12 | kismayo
# Processing Record 25 of Set 12 | hit
# Processing Record 26 of Set 12 | nova sintra
# Processing Record 27 of Set 12 | sadovoye
# Processing Record 28 of Set 12 | vodnyy
# Processing Record 29 of Set 12 | adi keyh
# Processing Record 30 of Set 12 | tralee
# Processing Record 31 of Set 12 | cabo san lucas
# Processing Record 32 of Set 12 | maragogi
# Processing Record 33 of Set 12 | maintirano
# Processing Record 34 of Set 12 | awjilah
# Processing Record 35 of Set 12 | tamandare
# Processing Record 36 of Set 12 | karlskrona
# Processing Record 37 of Set 12 | antsiranana
# Processing Record 38 of Set 12 | sibay
# Processing Record 39 of Set 12 | vitez
# Processing Record 40 of Set 12 | trelew
# Processing Record 41 of Set 12 | okha
# Processing Record 42 of Set 12 | cookeville
# Processing Record 43 of Set 12 | raychikhinsk
# Processing Record 44 of Set 12 | revda
# Processing Record 45 of Set 12 | iisalmi
# Processing Record 46 of Set 12 | lerwick
# Processing Record 47 of Set 12 | norrtalje
# Processing Record 48 of Set 12 | torghay
# Processing Record 49 of Set 12 | shindand
# Processing Record 0 of Set 13 | alotau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  east london -33.0153   27.9116     62.67        88         100        4.09
# 1    jamestown  42.0970  -79.2353     49.01        95         100       12.66
# 2     bilibino  68.0546  166.4372     -0.11        98         100        1.01
# 3     waitangi -43.9535 -176.5597     57.81        97         100        8.99
# 4       bethel  41.3712  -73.4140     57.90        45           0        8.05
#
#   Country        Date
# 0      ZA  1731267352
# 1      US  1731267173
# 2      RU  1731267397
# 3      NZ  1731267398
# 4      US  1731267399

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        east london -33.0153   27.9116     62.67        88         100
# 1          jamestown  42.0970  -79.2353     49.01        95         100
# 2           bilibino  68.0546  166.4372     -0.11        98         100
# 3           waitangi -43.9535 -176.5597     57.81        97         100
# 4             bethel  41.3712  -73.4140     57.90        45           0
#
#          Wind Speed Country        Date
# City_ID
# 0              4.09      ZA  1731267352
# 1             12.66      US  1731267173
# 2              1.01      RU  1731267397
# 3              8.99      NZ  1731267398
# 4              8.05      US  1731267399

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
plt.scatter(lats, max_temps, edgecolor="black", linewidth = 1, marker = "o", alpha = 0.8, label = "Cities" )

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Latitude Vs. Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
humidity = city_data_df["Humidity"]
plt.scatter(lats, humidity, edgecolor="black", linewidth = 1, marker = "o", alpha = 0.8, label = "Cities" )

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
cloudiness  = city_data_df["Cloudiness"]
plt.scatter(lats, cloudiness, edgecolor = "black", alpha = 0.8, marker = "o", label = "Cities", linewidth = 1)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitide vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
wind_speed = city_data_df["Wind Speed"]
plt.scatter(lats, wind_speed, edgecolor = "black", linewidth = 1, alpha = 0.8, marker = "o", label = "Cities")
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    #plt.title(title)
    #plt.xlabel("Latitude")
    #plt.ylabel("Max Temp")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
Latitude = city_data_df["Lat"]
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        jamestown  42.0970  -79.2353     49.01        95         100
# 2         bilibino  68.0546  166.4372     -0.11        98         100
# 4           bethel  41.3712  -73.4140     57.90        45           0
# 5          klyuchi  52.2667   79.1667     32.25        92         100
# 8            mejit  10.2753  170.8646     82.96        76           2
#
#          Wind Speed Country        Date
# City_ID
# 1             12.66      US  1731267173
# 2              1.01      RU  1731267397
# 4              8.05      US  1731267399
# 5             17.72      RU  1731267400
# 8             19.33      MH  1731267405

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
Latitude = city_data_df["Lat"]
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              east london -33.0153   27.9116     62.67        88         100
# 3                 waitangi -43.9535 -176.5597     57.81        97         100
# 6               queenstown -31.8976   26.8753     55.06        93         100
# 7        port-aux-francais -49.3500   70.2167     39.96        84          58
# 13                necochea -38.5473  -58.7368     56.97        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.09      ZA  1731267352
# 3              8.99      NZ  1731267398
# 6              5.48      ZA  1731267402
# 7             21.92      TF  1731267403
# 13            17.65      AR  1731267410

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp", (6, 30))
# Out:
# The r-squared is: 0.7634637604100786

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp", (-30, 20))
# Out:
# The r-squared is: 0.523669934648753

# %%
#**Discussion about the linear relationship:** R-Squared value (52.37%) more than 50% so we can accept it but a large amount of data not represent the actual analysis

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (6, 30))
# Out:
# The r-squared is: 0.09695128204851369

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (-30, 30))
# Out:
# The r-squared is: 0.020928184837010023

# %% [markdown]
# **Discussion about the linear relationship:** R-Squared value (2%) is near 0 so it is not acceptable. At least above 50% will be acceptable

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (6, 30))
# Out:
# The r-squared is: 0.03433471373307972

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (-30, 10))
# Out:
# The r-squared is: 0.004843136454216233

# %% [markdown]
# **Discussion about the linear relationship:**  R-Squared value is 0% so it is not acceptable. At least above 50% will be acceptable

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (4, 20))
# Out:
# The r-squared is: 0.0059749182178936745

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (-50, 20))
# Out:
# The r-squared is: 0.08019727184490816

# %% [markdown]
# **Discussion about the linear relationship:** R-Squared value is 8% so it is not acceptable. At least above 50% will be acceptable
